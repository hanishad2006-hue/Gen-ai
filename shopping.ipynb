# %% [markdown]
# <a href="https://colab.research.google.com/github/hanishad2006-hue/Gen-ai/blob/main/shopping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd
df=pd.read_csv("/content/Shopping_data.csv")

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.tail()
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
df.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info
# Out:
# <bound method DataFrame.info of      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]>

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(x='Genre',data=df,color='blue')
# Out:
# <Axes: xlabel='Genre', ylabel='count'>

# %%
sns.barplot(x='Genre',y='Age',data=df,color='pink')
# Out:
# <Axes: xlabel='Genre', ylabel='Age'>

# %%
sns.scatterplot(x='Annual Income (k$)',y='Age',data=df,color='orange')
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Age'>

# %%
df[['Annual Income (k$)','Age']]
# Out:
#      Annual Income (k$)  Age
# 0                    15   19
# 1                    15   21
# 2                    16   20
# 3                    16   23
# 4                    17   31
# ..                  ...  ...
# 195                 120   35
# 196                 126   45
# 197                 126   32
# 198                 137   32
# 199                 137   30
#
# [200 rows x 2 columns]

# %%
corr=df.corr(numeric_only=True)
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
corr=df.corr(numeric_only=False)
corr=df.corr(numeric_only=True)
sns.heatmap(corr,annot=False)
# Out:
# <Axes: >

# %%
pip install scikit-learn

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['CustomerID']=le.fit_transform(df['CustomerID'])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Genre']=le.fit_transform(df['Genre'])

# %%
df
# Out:
#      CustomerID  Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             0      1   19                  15                      39
# 1             1      1   21                  15                      81
# 2             2      0   20                  16                       6
# 3             3      0   23                  16                      77
# 4             4      0   31                  17                      40
# ..          ...    ...  ...                 ...                     ...
# 195         195      0   35                 120                      79
# 196         196      0   45                 126                      28
# 197         197      1   32                 126                      74
# 198         198      1   32                 137                      18
# 199         199      1   30                 137                      83
#
# [200 rows x 5 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()
df['Genre']=oe.fit_transform(df[['Genre']])

# %%
df
# Out:
#      CustomerID  Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             0    1.0   19                  15                      39
# 1             1    1.0   21                  15                      81
# 2             2    0.0   20                  16                       6
# 3             3    0.0   23                  16                      77
# 4             4    0.0   31                  17                      40
# ..          ...    ...  ...                 ...                     ...
# 195         195    0.0   35                 120                      79
# 196         196    0.0   45                 126                      28
# 197         197    1.0   32                 126                      74
# 198         198    1.0   32                 137                      18
# 199         199    1.0   30                 137                      83
#
# [200 rows x 5 columns]

# %%
#df['Annual Income (k$)']=df['Annual Income (k$)'].fillna(df['Annual Income (k$)'].mode()(0))
#df['Annual Income (k$)']=df['Annual Income (k$)'].fillna(df['Annual Income (k$)'].mean()(0))

# %%
df.describe()
# Out:
#        CustomerID       Genre         Age  Annual Income (k$)  \
# count  200.000000  200.000000  200.000000          200.000000
# mean    99.500000    0.440000   38.850000           60.560000
# std     57.879185    0.497633   13.969007           26.264721
# min      0.000000    0.000000   18.000000           15.000000
# 25%     49.750000    0.000000   28.750000           41.500000
# 50%     99.500000    0.000000   36.000000           61.500000
# 75%    149.250000    1.000000   49.000000           78.000000
# max    199.000000    1.000000   70.000000          137.000000
#
#        Spending Score (1-100)
# count              200.000000
# mean                50.200000
# std                 25.823522
# min                  1.000000
# 25%                 34.750000
# 50%                 50.000000
# 75%                 73.000000
# max                 99.000000

# %%
df.dropna(columns='':1,axis)
